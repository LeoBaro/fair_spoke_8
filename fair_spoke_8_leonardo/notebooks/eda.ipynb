# %%
from datasets import load_dataset
from tqdm.notebook import tqdm
from pathlib import Path
import polars as pl

pl.Config(fmt_str_lengths=1000, tbl_width_chars=1000)

# %%
ds = load_dataset("yuvalkirstain/laion-hd-subset", split=None)

# %%
# count = 0
# for item in ds['train']:
#     print(item.values())
#     count += 1
#     if count ==20:
#         print(item.keys())
#         break

# %%
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

def clean_text(text):
    # 1) Lowercase
    text = text.lower()
    
    # 2) Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # 2.5) Remove non-ascii characters
    text = text.encode("ascii", "ignore").decode()
    
    # 3) Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # 4) Tokenize
    tokens = nltk.word_tokenize(text)
    
    # 5) Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if w not in stop_words]
    
    # 6) Lemmatize
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(w) for w in tokens]
    
    # 7) Remove extra whitespace / rejoin if desired
    cleaned_text = " ".join(tokens)
    
    return cleaned_text

# # Example usage
# raw_text = "Hello there!!! This is a sample text, containing numbers like 123 and punctuation."
# cleaned = clean_text(raw_text)
# print(cleaned)
# # Output might be: "hello sample text containing number like punctuation"
# Out:
# [nltk_data] Downloading package punkt to /home/fbernardi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/fbernardi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/fbernardi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def filter_captions(caption, min_words=2, min_chars=5):
    # Strip leading/trailing whitespace
    cap = caption.strip()
    
    # Split the caption into words
    words = cap.split()
    
    # Count characters (excluding leading/trailing whitespace)
    char_count = len(cap)
    
    # Check conditions
    condition =  len(words) > min_words and char_count > min_chars
    
    return condition

# %%
df_train['caption']
# Out:
# shape: (13_451,)
# Series: 'caption' [str]
# [
# 	"Odisha - 2 : Simlipal"
# 	"Page 15"
# 	"18th century man silhouettes"
# 	"¡Ánimo juventud! (2020) 1080p WEB-DL Latino"
# 	""Landing Page Template namens ""Kids Tree Preschool"" #65801""
# 	…
# 	"SOFABAB"
# 	"From Dusk Till Dawn - The Trilogy (Blu-Ray) - 4"
# 	"Vintage Champion Grant Hill Jersey Medium"
# 	"SOFABAB"
# 	"Certified Pre-Owned 2019 Chevrolet Impala LT- Leather, Sunroof, Remote Start"
# ]

# %%
import fasttext
import os
import re

def fasttext_load_model(model_name: str, dir_name: str, cwd: str):
    try:
        model_path = os.path.join(cwd, dir_name, model_name)
        model = fasttext.load_model(model_path)
    except:
        parent_dir = os.path.dirname(cwd)
        return fasttext_load_model(model_name, dir_name, parent_dir)
    else:
        return model
    
def extract_str_from_pattern(s: str, regex: str) -> str:
    pattern = re.compile(regex)
    match = pattern.match(s)
    tot_groups = len(match.groups())
    matched_groups = match.groups(tot_groups)
    return matched_groups

def is_english_sentence(sentence: str):
    predictions, score = model.predict(sentence.strip().replace('\n', ' '))
    return {"is_english":predictions[0] == '__label__en', 
            "lang_detected":predictions[0], 
            "score":score[0]}

if __name__ == "__main__":
    model = fasttext_load_model('lid.176.bin', 'models', os.getcwd()) 
    input_file = "/home/fbernardi/Documents/fair_spoke_8/train_cap.txt"
    with open(input_file, 'r', encoding='utf-8') as f:
        for line in f:
            result = is_english_sentence(line)
            detected_lang = extract_str_from_pattern(result['lang_detected'], r'^__label__(.+)$')
            print(detected_lang[0], result)
# Out:
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.26760274171829224}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3941895663738251}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7033547759056091}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.5783684253692627}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6295984387397766}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8507919311523438}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.15321119129657745}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9842501282691956}
# ko {'is_english': False, 'lang_detected': '__label__ko', 'score': 0.7064388394355774}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.36353638768196106}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7940080761909485}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7092770934104919}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9822312593460083}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7573224902153015}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.33535513281822205}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.502135157585144}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9139513373374939}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9311313033103943}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.45398861169815063}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8392788767814636}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8351198434829712}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4597952663898468}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9518585205078125}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9814153909683228}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.31412315368652344}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6167075634002686}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.575511634349823}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.23237888514995575}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.5303000211715698}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7443511486053467}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7788610458374023}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6744489669799805}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.28362032771110535}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9998955130577087}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4457360804080963}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9714199304580688}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9824968576431274}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4615369737148285}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9085627198219299}
# hu {'is_english': False, 'lang_detected': '__label__hu', 'score': 0.9981155395507812}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7635655999183655}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6098848581314087}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9007279872894287}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5295830368995667}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.5472524762153625}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9659570455551147}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.18061329424381256}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7025020122528076}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5690588355064392}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9996011257171631}
# id {'is_english': False, 'lang_detected': '__label__id', 'score': 0.4995807409286499}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.2792036235332489}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7350449562072754}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9210714101791382}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.49942949414253235}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.5697444677352905}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9679041504859924}
# ko {'is_english': False, 'lang_detected': '__label__ko', 'score': 0.9272392392158508}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8192064166069031}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5174686908721924}
# no {'is_english': False, 'lang_detected': '__label__no', 'score': 0.775340735912323}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.2664845287799835}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4349685609340668}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.19692257046699524}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.40260064601898193}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7769810557365417}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6485536098480225}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.990195631980896}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4157288372516632}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4810551702976227}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.39241287112236023}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6509741544723511}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7250666618347168}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.492835134267807}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9908469319343567}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3494991958141327}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8025899529457092}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.8673593997955322}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.7548637986183167}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7686413526535034}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.2984446883201599}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.3854379653930664}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9099038243293762}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.8729322552680969}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.32770031690597534}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.24110691249370575}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.48832258582115173}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8211601972579956}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.25183844566345215}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6616194844245911}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9750413298606873}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6377144455909729}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9941832423210144}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.4375043511390686}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7712287902832031}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8143870830535889}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.49038806557655334}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48321548104286194}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4011539816856384}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4325183033943176}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.5146448612213135}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7237485647201538}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5107519626617432}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6807572841644287}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3833393156528473}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6504219174385071}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.30247268080711365}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.14571116864681244}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7304151058197021}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5775786638259888}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2527626156806946}
# fi {'is_english': False, 'lang_detected': '__label__fi', 'score': 0.4895854592323303}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8675642013549805}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9935925602912903}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9862371683120728}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4445769488811493}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8664640784263611}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.33414629101753235}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4760396480560303}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.31647688150405884}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4063185453414917}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.6017118096351624}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.4542328715324402}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.45631927251815796}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.564349353313446}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.46536391973495483}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7922425270080566}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3340998589992523}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.27663949131965637}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.565436840057373}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9898713231086731}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.391740083694458}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9961031079292297}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5259199142456055}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8312271237373352}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.2486943006515503}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.18336966633796692}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5166347026824951}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7671906352043152}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.144951730966568}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7840330600738525}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8644707202911377}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8551566004753113}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2554378807544708}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.45062652230262756}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7784488201141357}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.19258856773376465}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9982477426528931}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9597457647323608}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5172026753425598}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.19639503955841064}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7674031853675842}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.34239423274993896}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9728305339813232}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4720762372016907}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.9954748749732971}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6566556096076965}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6605887413024902}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6665359735488892}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4767504930496216}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5704373121261597}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7222353219985962}
# no {'is_english': False, 'lang_detected': '__label__no', 'score': 0.9211896657943726}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.24374628067016602}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5379094481468201}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.4337238371372223}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8782640099525452}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8229840993881226}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6032361388206482}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7972954511642456}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9903032779693604}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.39191368222236633}
# no {'is_english': False, 'lang_detected': '__label__no', 'score': 0.42570772767066956}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48010653257369995}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4417324662208557}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7383641004562378}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5093211531639099}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6183897256851196}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6615883708000183}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.295073002576828}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9854011535644531}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4285227060317993}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6588979959487915}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6393857002258301}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7429349422454834}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7661834955215454}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5217896103858948}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6560513377189636}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4754202663898468}
# vi {'is_english': False, 'lang_detected': '__label__vi', 'score': 0.9053350687026978}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6664378046989441}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7529090642929077}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.863717257976532}
# vi {'is_english': False, 'lang_detected': '__label__vi', 'score': 0.9978878498077393}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5717199444770813}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5328165292739868}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9983401894569397}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.37549400329589844}
# oc {'is_english': False, 'lang_detected': '__label__oc', 'score': 0.33809694647789}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6591494083404541}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7559407949447632}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8654748797416687}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9812047481536865}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2731480300426483}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.647161602973938}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.46378034353256226}
# da {'is_english': False, 'lang_detected': '__label__da', 'score': 0.22080135345458984}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7521524429321289}
# ar {'is_english': False, 'lang_detected': '__label__ar', 'score': 0.9960770010948181}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5690737962722778}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5158094167709351}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9921494722366333}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9188166260719299}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.45578745007514954}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6068877577781677}
# id {'is_english': False, 'lang_detected': '__label__id', 'score': 0.2744998335838318}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4699608087539673}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.8763003945350647}
# no {'is_english': False, 'lang_detected': '__label__no', 'score': 0.30046921968460083}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7459593415260315}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6256078481674194}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8110277652740479}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.2241363525390625}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3974747657775879}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.21935521066188812}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6131278276443481}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.616306722164154}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6297990679740906}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.31426844000816345}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.5035833716392517}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9141145348548889}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8542876839637756}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.2085864096879959}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.838646650314331}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.784247100353241}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.22464619576931}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5465202927589417}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9512249827384949}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7388688325881958}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.42994242906570435}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8510633707046509}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.38221803307533264}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.8709607124328613}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9417694807052612}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.15805576741695404}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4080308973789215}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.15207238495349884}
# nl {'is_english': False, 'lang_detected': '__label__nl', 'score': 0.9974766969680786}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.689988374710083}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4335015118122101}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.2416539341211319}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8386228084564209}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.931882917881012}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.15189041197299957}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.535939633846283}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.28588399291038513}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9670650959014893}
# uk {'is_english': False, 'lang_detected': '__label__uk', 'score': 0.453829824924469}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6330241560935974}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6440622210502625}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4921973645687103}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5876522660255432}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6924354434013367}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.448568731546402}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7079824805259705}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.43924784660339355}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.913894534111023}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5345512628555298}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8476046323776245}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.6202174425125122}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.39272618293762207}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9908279180526733}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.45668619871139526}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8140762448310852}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6060208678245544}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5813605189323425}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.7750616669654846}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.6750892996788025}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.58778315782547}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9261481165885925}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3890162706375122}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6069198846817017}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6193118691444397}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.48757055401802063}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9946245551109314}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.4626823365688324}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9713819026947021}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4444563090801239}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7035501599311829}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7448170185089111}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9989043474197388}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7189890742301941}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.9878439903259277}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.21881839632987976}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7371019124984741}
# ceb {'is_english': False, 'lang_detected': '__label__ceb', 'score': 0.33643776178359985}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9996435642242432}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7789823412895203}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3994552791118622}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5778086185455322}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6482449769973755}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6015053391456604}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.10211829841136932}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.527159571647644}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5240997672080994}
# sv {'is_english': False, 'lang_detected': '__label__sv', 'score': 0.2724166512489319}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9639685153961182}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.8788033127784729}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.1541380137205124}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9948097467422485}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4218118488788605}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6378975510597229}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.5391913652420044}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.49923545122146606}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.25507938861846924}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8064863681793213}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3978065848350525}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6100530028343201}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.267014741897583}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5553925037384033}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5379267930984497}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6124693155288696}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6446144580841064}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7599809169769287}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9894362092018127}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.36536842584609985}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4729722738265991}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.50957852602005}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.11308182030916214}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9447755813598633}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6705044507980347}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8365702033042908}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5150622129440308}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7120133638381958}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.5398449301719666}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7654012441635132}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.5149072408676147}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.36842480301856995}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7363216876983643}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6766204833984375}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7162108421325684}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4306538701057434}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.589008092880249}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.7488915324211121}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.19982388615608215}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.999930202960968}
# fa {'is_english': False, 'lang_detected': '__label__fa', 'score': 0.9967975616455078}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6437777280807495}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6258605122566223}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5961153507232666}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5466489791870117}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9148123264312744}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5407240986824036}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.771430492401123}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.34358954429626465}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4149262607097626}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8055648803710938}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7058050632476807}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8860180377960205}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.27027228474617004}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.42508015036582947}
# sk {'is_english': False, 'lang_detected': '__label__sk', 'score': 0.48650261759757996}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3881825804710388}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6776043176651001}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9515281915664673}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9188348054885864}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.41768914461135864}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3484456539154053}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.6138010025024414}
# id {'is_english': False, 'lang_detected': '__label__id', 'score': 0.34705880284309387}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5256461501121521}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9058452248573303}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6440473794937134}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6991251707077026}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6814348697662354}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5038489103317261}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7481359839439392}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.8276476263999939}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48973286151885986}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9704861640930176}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6147037148475647}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.23058637976646423}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.716715931892395}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8045071363449097}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5565007925033569}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.1827932596206665}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4909185469150543}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.3114859461784363}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.44814515113830566}
# uk {'is_english': False, 'lang_detected': '__label__uk', 'score': 0.4310365617275238}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7218055725097656}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7184053063392639}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8351290822029114}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.7800074219703674}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6431941390037537}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6518819332122803}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8126082420349121}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6937227845191956}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2631145119667053}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.6111507415771484}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.666183590888977}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.40877237915992737}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6831637620925903}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7977142930030823}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5595982670783997}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.8171587586402893}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.1597328931093216}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5962253212928772}
# sv {'is_english': False, 'lang_detected': '__label__sv', 'score': 0.43350949883461}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8832709193229675}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7422646284103394}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.41696497797966003}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.3168502151966095}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.375365287065506}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5359454154968262}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6007354855537415}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5816135406494141}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.43768510222435}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7389475107192993}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.6889070868492126}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5642962455749512}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7716884613037109}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7165887951850891}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8847271800041199}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5762730836868286}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6182848811149597}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9788866639137268}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.32027268409729004}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 1.0000452995300293}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3687839210033417}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5347959399223328}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7162272930145264}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8921706676483154}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.17619581520557404}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.16874516010284424}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.18255598843097687}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.588330090045929}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2516065239906311}
# hr {'is_english': False, 'lang_detected': '__label__hr', 'score': 0.18523375689983368}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.3012637794017792}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9063279032707214}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4919091463088989}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5467280149459839}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7164754271507263}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.46150994300842285}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7650192379951477}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.8415122628211975}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4980475604534149}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9763512015342712}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5362474322319031}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9999254941940308}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8724201321601868}
# eo {'is_english': False, 'lang_detected': '__label__eo', 'score': 0.4399698078632355}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6780135631561279}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.6954265832901001}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.3987433910369873}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6868916153907776}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.40844932198524475}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7784914374351501}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4180065989494324}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6792135238647461}
# id {'is_english': False, 'lang_detected': '__label__id', 'score': 0.2663668692111969}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.27273887395858765}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7010903358459473}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3839215338230133}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5874220132827759}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.32206252217292786}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9998196959495544}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7223904132843018}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5866106152534485}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48641499876976013}
# sr {'is_english': False, 'lang_detected': '__label__sr', 'score': 0.2930489182472229}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6619887351989746}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3682968020439148}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.8641000986099243}
# nl {'is_english': False, 'lang_detected': '__label__nl', 'score': 0.6769239902496338}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.44766855239868164}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3746245801448822}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.47867441177368164}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.46852582693099976}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7412479519844055}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3113539516925812}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5809299945831299}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5791510939598083}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5078595876693726}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.35265591740608215}
# da {'is_english': False, 'lang_detected': '__label__da', 'score': 0.9444828629493713}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9925212264060974}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.561924397945404}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5596411824226379}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.3744759261608124}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9893888831138611}
# sv {'is_english': False, 'lang_detected': '__label__sv', 'score': 0.5152125358581543}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.29025086760520935}
# el {'is_english': False, 'lang_detected': '__label__el', 'score': 0.9378847479820251}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.45124372839927673}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9950709939002991}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6164100766181946}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6951436400413513}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7542175054550171}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5161848068237305}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8284584283828735}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4124246835708618}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.44824671745300293}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48410797119140625}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5886692404747009}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9753336906433105}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.8682035803794861}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9220760464668274}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.33611905574798584}
# vi {'is_english': False, 'lang_detected': '__label__vi', 'score': 0.9994508624076843}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.18946605920791626}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.16852430999279022}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6890952587127686}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9787819385528564}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.5339647531509399}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6855952143669128}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6461060047149658}
# no {'is_english': False, 'lang_detected': '__label__no', 'score': 0.37274637818336487}
# sv {'is_english': False, 'lang_detected': '__label__sv', 'score': 0.9970579147338867}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5699391961097717}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4592742919921875}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5899547338485718}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.41053956747055054}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5096309185028076}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7395716309547424}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4216151833534241}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6395947933197021}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.48711344599723816}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6846636533737183}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5144867897033691}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.35495302081108093}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9955858588218689}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7175348997116089}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9780555367469788}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.36046990752220154}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9841338992118835}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8704800009727478}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8985849618911743}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.692824125289917}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.9755738973617554}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.569682776927948}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6606125235557556}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9379631876945496}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5088328123092651}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.573074221611023}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.46655046939849854}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6487213373184204}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.77912837266922}
# lt {'is_english': False, 'lang_detected': '__label__lt', 'score': 0.4865741729736328}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3314574360847473}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5329428911209106}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7446019053459167}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6034135222434998}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6950617432594299}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6321449875831604}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9383753538131714}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4635028541088104}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8115756511688232}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6211522817611694}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6327557563781738}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6350226402282715}
# ...
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3297801613807678}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7290403842926025}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9047960638999939}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.8657052516937256}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7246347069740295}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5774986147880554}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6566798090934753}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.46346384286880493}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8359745740890503}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9976559281349182}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.8927342295646667}
# pt {'is_english': False, 'lang_detected': '__label__pt', 'score': 0.7680819034576416}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7903186678886414}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4204663634300232}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8664449453353882}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4037255346775055}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.8336246609687805}
# hr {'is_english': False, 'lang_detected': '__label__hr', 'score': 0.27169424295425415}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3657151162624359}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5751494765281677}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8761718273162842}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6715781092643738}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.409664124250412}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3746611773967743}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.47647714614868164}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6949616074562073}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8058214783668518}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5784055590629578}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6276000142097473}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9626790285110474}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.23613299429416656}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.652944028377533}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.45004644989967346}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6190162897109985}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.13327087461948395}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5139224529266357}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5381847023963928}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9307742714881897}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5808436870574951}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.913172721862793}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7425358295440674}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6812949180603027}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5531051158905029}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9911137819290161}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6192087531089783}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6420770287513733}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5076110363006592}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3852354884147644}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5112760663032532}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7005220055580139}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.41425877809524536}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7041071057319641}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8099969029426575}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4586678743362427}
# he {'is_english': False, 'lang_detected': '__label__he', 'score': 0.999972939491272}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7071943879127502}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.1828925907611847}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8598518967628479}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6808878183364868}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9099255204200745}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6553301811218262}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5423403382301331}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9940520524978638}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.29271984100341797}
# sv {'is_english': False, 'lang_detected': '__label__sv', 'score': 0.4687505066394806}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.1681673526763916}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8569060564041138}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.9995099306106567}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3183748424053192}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5484827160835266}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6657647490501404}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3647922873497009}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.23600618541240692}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6647813320159912}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.18386170268058777}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9444667100906372}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3777242600917816}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.8188971281051636}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7803525328636169}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.7103981375694275}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5464147329330444}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.8638734817504883}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5005244016647339}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6725809574127197}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2017139494419098}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.38962915539741516}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.4271339178085327}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9314401745796204}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9365890622138977}
# eo {'is_english': False, 'lang_detected': '__label__eo', 'score': 0.12194643169641495}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4482591450214386}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9631240963935852}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.1786133199930191}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7896130681037903}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.535658597946167}
# zh {'is_english': False, 'lang_detected': '__label__zh', 'score': 0.8485946655273438}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3962521553039551}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7111048102378845}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7116250991821289}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9999225735664368}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5120177865028381}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7808720469474792}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5501002073287964}
# pl {'is_english': False, 'lang_detected': '__label__pl', 'score': 0.9497016668319702}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.14844189584255219}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.8026844263076782}
# he {'is_english': False, 'lang_detected': '__label__he', 'score': 1.000043272972107}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8378419280052185}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.7202622890472412}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5181283354759216}
# it {'is_english': False, 'lang_detected': '__label__it', 'score': 0.7972623109817505}
# vi {'is_english': False, 'lang_detected': '__label__vi', 'score': 0.9949668049812317}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7490860819816589}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9975643157958984}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6584925055503845}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5844244360923767}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9378872513771057}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9885547757148743}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9985334277153015}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.9998656511306763}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9132822155952454}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6734178066253662}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9790164232254028}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9141266345977783}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8718404769897461}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.637517511844635}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4615800082683563}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.3971613049507141}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.25695163011550903}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7156884074211121}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.500898540019989}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.832566499710083}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.41951337456703186}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.8414461612701416}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.905776858329773}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8761642575263977}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.42943665385246277}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.14004305005073547}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.989525318145752}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4127230644226074}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.8487334847450256}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.18390415608882904}
# de {'is_english': False, 'lang_detected': '__label__de', 'score': 0.9866926670074463}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7791770696640015}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.9092563986778259}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.26988232135772705}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.4290234446525574}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9597905874252319}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8215507864952087}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.29954779148101807}
# ja {'is_english': False, 'lang_detected': '__label__ja', 'score': 0.30349302291870117}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.647488534450531}
# nl {'is_english': False, 'lang_detected': '__label__nl', 'score': 0.6707872152328491}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9849621653556824}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7741416692733765}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6424383521080017}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.28648826479911804}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.733879029750824}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.616240382194519}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.2676314115524292}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6610736846923828}
# fr {'is_english': False, 'lang_detected': '__label__fr', 'score': 0.9485036730766296}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.9757276177406311}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6975964307785034}
# ca {'is_english': False, 'lang_detected': '__label__ca', 'score': 0.5401936173439026}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.8848132491111755}
# ru {'is_english': False, 'lang_detected': '__label__ru', 'score': 0.9610901474952698}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.07435877621173859}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.28157371282577515}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5940268635749817}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.7862091064453125}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.25021037459373474}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.23783980309963226}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.542427122592926}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.7464203238487244}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6194458603858948}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.5277531147003174}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.34272512793540955}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.954738199710846}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6930794715881348}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.6328722238540649}
# nl {'is_english': False, 'lang_detected': '__label__nl', 'score': 0.14330053329467773}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.2027910202741623}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.43724825978279114}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.5431576371192932}
# es {'is_english': False, 'lang_detected': '__label__es', 'score': 0.2027910202741623}
# en {'is_english': True, 'lang_detected': '__label__en', 'score': 0.741841733455658}

# %%
subset = [
    'similarity',
    'hash',
    'punsafe',
    'pwatermark',
    'LANGUAGE',
    'caption',
    'url',
    'key',
    'width',
    'height',
    'original_width',
    'original_height'
]

splits = {'train': 'data/train-*-of-*.parquet', 'test': 'data/test-00000-of-00001-f5aa494af1d25f74.parquet'}
df_train = pl.read_parquet('hf://datasets/yuvalkirstain/laion-hd-subset/' + splits['train'])[subset]
df_test = pl.read_parquet('hf://datasets/yuvalkirstain/laion-hd-subset/' + splits['test'])[subset]

# %%
map_data_types = pl.Struct({
                        pl.Field("is_english", pl.Boolean),
                        pl.Field("lang_detected", pl.String),
                        pl.Field("score", pl.Float64)
                        })

# %%
df_train
# Out:
# shape: (13_451, 15)
# ┌────────────┬──────────────────────┬───────────┬────────────┬───┬─────────────────┬────────────┬───────────────┬──────────┐
# │ similarity ┆ hash                 ┆ punsafe   ┆ pwatermark ┆ … ┆ original_height ┆ is_english ┆ lang_detected ┆ score    │
# │ ---        ┆ ---                  ┆ ---       ┆ ---        ┆   ┆ ---             ┆ ---        ┆ ---           ┆ ---      │
# │ f64        ┆ i64                  ┆ f64       ┆ f64        ┆   ┆ i64             ┆ bool       ┆ str           ┆ f64      │
# ╞════════════╪══════════════════════╪═══════════╪════════════╪═══╪═════════════════╪════════════╪═══════════════╪══════════╡
# │ 0.264381   ┆ 8441708930180998904  ┆ 0.000175  ┆ 0.009912   ┆ … ┆ 1600            ┆ false      ┆ fr            ┆ 0.267603 │
# │ 0.284093   ┆ 1252282617735001209  ┆ 0.000183  ┆ null       ┆ … ┆ 1682            ┆ true       ┆ en            ┆ 0.39419  │
# │ 0.303465   ┆ 4131493839794366439  ┆ 0.000483  ┆ 0.478444   ┆ … ┆ 1475            ┆ true       ┆ en            ┆ 0.703355 │
# │ 0.266388   ┆ -5846660546473290352 ┆ 0.384948  ┆ 0.002599   ┆ … ┆ 1080            ┆ false      ┆ es            ┆ 0.578368 │
# │ 0.310429   ┆ 6939400869967208633  ┆ 0.000073  ┆ 0.295235   ┆ … ┆ 1250            ┆ true       ┆ en            ┆ 0.629598 │
# │ …          ┆ …                    ┆ …         ┆ …          ┆ … ┆ …               ┆ …          ┆ …             ┆ …        │
# │ 0.288857   ┆ -3754978981588788335 ┆ 0.000742  ┆ 0.402525   ┆ … ┆ 1683            ┆ false      ┆ es            ┆ 0.202791 │
# │ 0.32071    ┆ 8101346899319823492  ┆ 0.002733  ┆ 0.29081    ┆ … ┆ 1567            ┆ true       ┆ en            ┆ 0.437248 │
# │ 0.330339   ┆ -230864369060936050  ┆ 0.000091  ┆ 0.327558   ┆ … ┆ 2048            ┆ true       ┆ en            ┆ 0.543158 │
# │ 0.296867   ┆ 5094972792430996628  ┆ 0.000742  ┆ 0.402556   ┆ … ┆ 1683            ┆ false      ┆ es            ┆ 0.202791 │
# │ 0.311854   ┆ -3649928615745462001 ┆ 3.2266e-7 ┆ 0.077521   ┆ … ┆ 1067            ┆ true       ┆ en            ┆ 0.741842 │
# └────────────┴──────────────────────┴───────────┴────────────┴───┴─────────────────┴────────────┴───────────────┴──────────┘

# %%
df_train['hash'].unique().count() == df_train.shape[0]
# Out:
# True

# %%
df_train.shape[0]
# Out:
# 13451

# %%
df_train['key'].unique()
# Out:
# shape: (13_451,)
# Series: 'key' [str]
# [
# 	"000011949"
# 	"000013817"
# 	"000010617"
# 	"000005204"
# 	"000000700"
# 	…
# 	"000012328"
# 	"000002313"
# 	"000013787"
# 	"000003701"
# 	"000004166"
# ]

# %%
df_train['LANGUAGE'].value_counts().sort('count', descending=True)
# Out:
# shape: (91, 2)
# ┌──────────┬───────┐
# │ LANGUAGE ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ en       ┆ 5911  │
# │ nolang   ┆ 3219  │
# │ fr       ┆ 379   │
# │ de       ┆ 354   │
# │ ru       ┆ 299   │
# │ …        ┆ …     │
# │ tg       ┆ 2     │
# │ mi       ┆ 2     │
# │ bn       ┆ 1     │
# │ ka       ┆ 1     │
# │ sd       ┆ 1     │
# └──────────┴───────┘

# %%
df_train = df_train.with_columns(
       df_train['caption'].map_elements(lambda x: is_english_sentence(x), return_dtype=map_data_types, skip_nulls=True).alias('lang_detection')
).unnest("lang_detection")

# %%
df_train
# Out:
# shape: (13_451, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ similarit ┆ hash      ┆ punsafe   ┆ pwatermar ┆ … ┆ original_ ┆ is_englis ┆ lang_dete ┆ score    │
# │ y         ┆ ---       ┆ ---       ┆ k         ┆   ┆ height    ┆ h         ┆ cted      ┆ ---      │
# │ ---       ┆ i64       ┆ f64       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ f64      │
# │ f64       ┆           ┆           ┆ f64       ┆   ┆ i64       ┆ bool      ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0.264381  ┆ 844170893 ┆ 0.000175  ┆ 0.009912  ┆ … ┆ 1600      ┆ false     ┆ __label__ ┆ 0.267603 │
# │           ┆ 018099890 ┆           ┆           ┆   ┆           ┆           ┆ fr        ┆          │
# │           ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.284093  ┆ 125228261 ┆ 0.000183  ┆ null      ┆ … ┆ 1682      ┆ true      ┆ __label__ ┆ 0.39419  │
# │           ┆ 773500120 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.303465  ┆ 413149383 ┆ 0.000483  ┆ 0.478444  ┆ … ┆ 1475      ┆ true      ┆ __label__ ┆ 0.703355 │
# │           ┆ 979436643 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.266388  ┆ -58466605 ┆ 0.384948  ┆ 0.002599  ┆ … ┆ 1080      ┆ false     ┆ __label__ ┆ 0.578368 │
# │           ┆ 464732903 ┆           ┆           ┆   ┆           ┆           ┆ es        ┆          │
# │           ┆ 52        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.310429  ┆ 693940086 ┆ 0.000073  ┆ 0.295235  ┆ … ┆ 1250      ┆ true      ┆ __label__ ┆ 0.629598 │
# │           ┆ 996720863 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 3         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 0.288857  ┆ -37549789 ┆ 0.000742  ┆ 0.402525  ┆ … ┆ 1683      ┆ false     ┆ __label__ ┆ 0.202791 │
# │           ┆ 815887883 ┆           ┆           ┆   ┆           ┆           ┆ es        ┆          │
# │           ┆ 35        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.32071   ┆ 810134689 ┆ 0.002733  ┆ 0.29081   ┆ … ┆ 1567      ┆ true      ┆ __label__ ┆ 0.437248 │
# │           ┆ 931982349 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 2         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.330339  ┆ -23086436 ┆ 0.000091  ┆ 0.327558  ┆ … ┆ 2048      ┆ true      ┆ __label__ ┆ 0.543158 │
# │           ┆ 906093605 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 0         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.296867  ┆ 509497279 ┆ 0.000742  ┆ 0.402556  ┆ … ┆ 1683      ┆ false     ┆ __label__ ┆ 0.202791 │
# │           ┆ 243099662 ┆           ┆           ┆   ┆           ┆           ┆ es        ┆          │
# │           ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.311854  ┆ -36499286 ┆ 3.2266e-7 ┆ 0.077521  ┆ … ┆ 1067      ┆ true      ┆ __label__ ┆ 0.741842 │
# │           ┆ 157454620 ┆           ┆           ┆   ┆           ┆           ┆ en        ┆          │
# │           ┆ 01        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_train = df_train.with_columns(
    df_train['lang_detected'].map_elements(
        lambda x: extract_str_from_pattern(x, r'^__label__(.+)$')[0], 
        return_dtype=pl.String, 
        skip_nulls=False)
)

# %%
df_train
# Out:
# shape: (13_451, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ similarit ┆ hash      ┆ punsafe   ┆ pwatermar ┆ … ┆ original_ ┆ is_englis ┆ lang_dete ┆ score    │
# │ y         ┆ ---       ┆ ---       ┆ k         ┆   ┆ height    ┆ h         ┆ cted      ┆ ---      │
# │ ---       ┆ i64       ┆ f64       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ f64      │
# │ f64       ┆           ┆           ┆ f64       ┆   ┆ i64       ┆ bool      ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0.264381  ┆ 844170893 ┆ 0.000175  ┆ 0.009912  ┆ … ┆ 1600      ┆ false     ┆ fr        ┆ 0.267603 │
# │           ┆ 018099890 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 4         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.284093  ┆ 125228261 ┆ 0.000183  ┆ null      ┆ … ┆ 1682      ┆ true      ┆ en        ┆ 0.39419  │
# │           ┆ 773500120 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.303465  ┆ 413149383 ┆ 0.000483  ┆ 0.478444  ┆ … ┆ 1475      ┆ true      ┆ en        ┆ 0.703355 │
# │           ┆ 979436643 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.266388  ┆ -58466605 ┆ 0.384948  ┆ 0.002599  ┆ … ┆ 1080      ┆ false     ┆ es        ┆ 0.578368 │
# │           ┆ 464732903 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 52        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.310429  ┆ 693940086 ┆ 0.000073  ┆ 0.295235  ┆ … ┆ 1250      ┆ true      ┆ en        ┆ 0.629598 │
# │           ┆ 996720863 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 3         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 0.288857  ┆ -37549789 ┆ 0.000742  ┆ 0.402525  ┆ … ┆ 1683      ┆ false     ┆ es        ┆ 0.202791 │
# │           ┆ 815887883 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 35        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.32071   ┆ 810134689 ┆ 0.002733  ┆ 0.29081   ┆ … ┆ 1567      ┆ true      ┆ en        ┆ 0.437248 │
# │           ┆ 931982349 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 2         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.330339  ┆ -23086436 ┆ 0.000091  ┆ 0.327558  ┆ … ┆ 2048      ┆ true      ┆ en        ┆ 0.543158 │
# │           ┆ 906093605 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 0         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.296867  ┆ 509497279 ┆ 0.000742  ┆ 0.402556  ┆ … ┆ 1683      ┆ false     ┆ es        ┆ 0.202791 │
# │           ┆ 243099662 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0.311854  ┆ -36499286 ┆ 3.2266e-7 ┆ 0.077521  ┆ … ┆ 1067      ┆ true      ┆ en        ┆ 0.741842 │
# │           ┆ 157454620 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 01        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(
                    rows=2, cols=1,
                    shared_xaxes=True,
                    vertical_spacing=0.03,
                    subplot_titles=("Dataset Language", "Language Detected")
                    )

fig.add_trace(
    go.Bar(
        x=df_train['LANGUAGE'].value_counts().sort('count', descending=False)['count'].to_list(), 
        y=df_train['LANGUAGE'].value_counts().sort('count', descending=False)['LANGUAGE'].to_list(),
        orientation='h'
        ),
    row=1, col=1
)

fig.add_trace(
    go.Bar(
        x=df_train['lang_detected'].value_counts().sort('count', descending=False)['count'].to_list(), 
        y=df_train['lang_detected'].value_counts().sort('count', descending=False)['lang_detected'].to_list(),
        orientation='h'
        ),
    row=2, col=1
)

fig.update_layout(height=800, width=1000, title_text="Side By Side Subplots")
fig.show()

# %%
# Same Detected Language

df_train.filter(
    (pl.col('LANGUAGE') == pl.col('lang_detected'))
).select(['LANGUAGE', 'lang_detected', 'caption'])
# Out:
# shape: (7_828, 3)
# ┌──────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                                                                                            │
# │ ---      ┆ ---           ┆ ---                                                                                                                                                │
# │ str      ┆ str           ┆ str                                                                                                                                                │
# ╞══════════╪═══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ en       ┆ en            ┆ Page 15                                                                                                                                            │
# │ en       ┆ en            ┆ 18th century man silhouettes                                                                                                                       │
# │ en       ┆ en            ┆ Men's Fanatics Branded Orange Florida Gators Personalized Basketball Pullover Hoodie 3                                                             │
# │ en       ┆ en            ┆ Happee Birthdae 3x4 Stamp Set                                                                                                                      │
# │ de       ┆ de            ┆ """ND Filter - auch """"Sonnenbrille für das Objektiv"""" genannt"""                                                                               │
# │ …        ┆ …             ┆ …                                                                                                                                                  │
# │ en       ┆ en            ┆ Mini Skirts for Fall Under $50 & On Mondays We Link Up by popular Chicago fashion blog, Glass of Glam: image of a woman wearing a fall mini skirt. │
# │ es       ┆ es            ┆ Villa a la venta en la Cala de la Granadella con vistas al mar - Javea - Costa Blanca                                                              │
# │ en       ┆ en            ┆ From Dusk Till Dawn - The Trilogy (Blu-Ray) - 4                                                                                                    │
# │ en       ┆ en            ┆ Vintage Champion Grant Hill Jersey Medium                                                                                                          │
# │ en       ┆ en            ┆ Certified Pre-Owned 2019 Chevrolet Impala LT- Leather, Sunroof, Remote Start                                                                       │
# └──────────┴───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Only Detected Language

df_train.filter(
    (pl.col('LANGUAGE') == "nolang")
).select(['LANGUAGE', 'lang_detected', 'caption'])
# Out:
# shape: (3_219, 3)
# ┌──────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                                                                                        │
# │ ---      ┆ ---           ┆ ---                                                                                                                                            │
# │ str      ┆ str           ┆ str                                                                                                                                            │
# ╞══════════╪═══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ nolang   ┆ en            ┆ "Landing Page Template namens ""Kids Tree Preschool"" #65801"                                                                                  │
# │ nolang   ┆ en            ┆ Ottawa Karaoke | Karaoke Wednesday, Friday, Sunday                                                                                             │
# │ nolang   ┆ en            ┆ "Untitled, 2013, wood, paint, nails, 12-3/4 x 3 x 20"""                                                                                        │
# │ nolang   ┆ zh            ┆ Re:[原创]【KMG】长水机场一组 1600大图 BOEING 737-700 B-2503 中国昆明长水国际机场                                                               │
# │ nolang   ┆ en            ┆ NUNA, 2019 MIXX<sup>™</sup> Stroller & PIPA<sup>™</sup> Lite LX Infant Car Seat Set Travel System, Alternate thumbnail 4, color, VERONA CAVIAR │
# │ …        ┆ …             ┆ …                                                                                                                                              │
# │ nolang   ┆ en            ┆ [MyGirl] Vol.012 Yu Zhu 23P, Lovely, Pure, Yu Zhu                                                                                              │
# │ nolang   ┆ en            ┆ Marvel Secret Warriors Rising Daisy Johnson MARVEL'S QUAKE Identity Doll Gift                                                                  │
# │ nolang   ┆ en            ┆ Attorney Desk                                                                                                                                  │
# │ nolang   ┆ en            ┆ Heart Health                                                                                                                                   │
# │ nolang   ┆ nl            ┆ weddingblogmannring-151.jpg                                                                                                                    │
# └──────────┴───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Different Detected Language

df_train.filter(
    (pl.col('LANGUAGE') != "nolang")
    & (pl.col('LANGUAGE') != pl.col('lang_detected'))
).select(['LANGUAGE', 'lang_detected', 'caption'])
# Out:
# shape: (2_404, 3)
# ┌──────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                                                    │
# │ ---      ┆ ---           ┆ ---                                                                                                        │
# │ str      ┆ str           ┆ str                                                                                                        │
# ╞══════════╪═══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ sw       ┆ fr            ┆ Odisha - 2 : Simlipal                                                                                      │
# │ lt       ┆ es            ┆ ¡Ánimo juventud! (2020) 1080p WEB-DL Latino                                                                │
# │ fil      ┆ en            ┆ Espinosa Crema No. 4 Robusto Cigars - 5.5 x 52 (Pack of 5)                                                 │
# │ lb       ┆ de            ┆ 3D Stadt New York 433 Rutschfest Büro Schreibtisch Schreibtisch Schreibtisch Mauspad Tastatur Spiel e136a0 │
# │ ca       ┆ zh            ┆ T-SHIRT - 300 REC                                                                                          │
# │ …        ┆ …             ┆ …                                                                                                          │
# │ bg       ┆ en            ┆ Audi RS 3                                                                                                  │
# │ en       ┆ es            ┆ Infactory Blacklight-esmalte de uñas con Glow-in-the-dark-efecto: Amazon.es: Belleza                       │
# │ it       ┆ en            ┆ Lamborghini Gallardo by Cosa Design                                                                        │
# │ ja       ┆ es            ┆ SOFABAB                                                                                                    │
# │ ja       ┆ es            ┆ SOFABAB                                                                                                    │
# └──────────┴───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df_train['is_english'].value_counts()
# Out:
# shape: (2, 2)
# ┌────────────┬───────┐
# │ is_english ┆ count │
# │ ---        ┆ ---   │
# │ bool       ┆ u32   │
# ╞════════════╪═══════╡
# │ false      ┆ 3993  │
# │ true       ┆ 9458  │
# └────────────┴───────┘

# %%
# English Captions

df_train.filter(
    (pl.col('LANGUAGE') == 'en')
    & (pl.col('lang_detected') == 'en')
)['LANGUAGE', 'lang_detected', 'caption']
# Out:
# shape: (5_645, 3)
# ┌──────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                                                                                            │
# │ ---      ┆ ---           ┆ ---                                                                                                                                                │
# │ str      ┆ str           ┆ str                                                                                                                                                │
# ╞══════════╪═══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ en       ┆ en            ┆ Page 15                                                                                                                                            │
# │ en       ┆ en            ┆ 18th century man silhouettes                                                                                                                       │
# │ en       ┆ en            ┆ Men's Fanatics Branded Orange Florida Gators Personalized Basketball Pullover Hoodie 3                                                             │
# │ en       ┆ en            ┆ Happee Birthdae 3x4 Stamp Set                                                                                                                      │
# │ en       ┆ en            ┆ 308/4 Honeysuckle Drive, Newcastle                                                                                                                 │
# │ …        ┆ …             ┆ …                                                                                                                                                  │
# │ en       ┆ en            ┆ Nfl Atlanta Falcons Nike Champ Drive Sideline Full Zip Jacket Black Zip Jackets Jackets Stylish Jackets                                            │
# │ en       ┆ en            ┆ Mini Skirts for Fall Under $50 & On Mondays We Link Up by popular Chicago fashion blog, Glass of Glam: image of a woman wearing a fall mini skirt. │
# │ en       ┆ en            ┆ From Dusk Till Dawn - The Trilogy (Blu-Ray) - 4                                                                                                    │
# │ en       ┆ en            ┆ Vintage Champion Grant Hill Jersey Medium                                                                                                          │
# │ en       ┆ en            ┆ Certified Pre-Owned 2019 Chevrolet Impala LT- Leather, Sunroof, Remote Start                                                                       │
# └──────────┴───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Detected English Captions

df_train.filter(
    (pl.col('LANGUAGE') != 'en')
    & (pl.col('lang_detected') == 'en')
)['LANGUAGE', 'lang_detected', 'caption']
# Out:
# shape: (3_813, 3)
# ┌──────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                                                                                        │
# │ ---      ┆ ---           ┆ ---                                                                                                                                            │
# │ str      ┆ str           ┆ str                                                                                                                                            │
# ╞══════════╪═══════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ nolang   ┆ en            ┆ "Landing Page Template namens ""Kids Tree Preschool"" #65801"                                                                                  │
# │ nolang   ┆ en            ┆ Ottawa Karaoke | Karaoke Wednesday, Friday, Sunday                                                                                             │
# │ nolang   ┆ en            ┆ "Untitled, 2013, wood, paint, nails, 12-3/4 x 3 x 20"""                                                                                        │
# │ fil      ┆ en            ┆ Espinosa Crema No. 4 Robusto Cigars - 5.5 x 52 (Pack of 5)                                                                                     │
# │ nolang   ┆ en            ┆ NUNA, 2019 MIXX<sup>™</sup> Stroller & PIPA<sup>™</sup> Lite LX Infant Car Seat Set Travel System, Alternate thumbnail 4, color, VERONA CAVIAR │
# │ …        ┆ …             ┆ …                                                                                                                                              │
# │ nolang   ┆ en            ┆ [MyGirl] Vol.012 Yu Zhu 23P, Lovely, Pure, Yu Zhu                                                                                              │
# │ nolang   ┆ en            ┆ Marvel Secret Warriors Rising Daisy Johnson MARVEL'S QUAKE Identity Doll Gift                                                                  │
# │ nolang   ┆ en            ┆ Attorney Desk                                                                                                                                  │
# │ nolang   ┆ en            ┆ Heart Health                                                                                                                                   │
# │ it       ┆ en            ┆ Lamborghini Gallardo by Cosa Design                                                                                                            │
# └──────────┴───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Detected English Captions

df_train.filter(
    (pl.col('LANGUAGE') == 'en')
    & (pl.col('lang_detected') != 'en')
)['LANGUAGE', 'lang_detected', 'caption']#.sample(10)
# Out:
# shape: (266, 3)
# ┌──────────┬───────────────┬──────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                              │
# │ ---      ┆ ---           ┆ ---                                                                                  │
# │ str      ┆ str           ┆ str                                                                                  │
# ╞══════════╪═══════════════╪══════════════════════════════════════════════════════════════════════════════════════╡
# │ en       ┆ fr            ┆ fruits-oranges-tangerines                                                            │
# │ en       ┆ es            ┆ FACTO / 2501 CHAIR                                                                   │
# │ en       ┆ ja            ┆ QUIRKY DAYTIME                                                                       │
# │ en       ┆ es            ┆ AXEL DENIM JACKET.                                                                   │
# │ en       ┆ fr            ┆ Used 2017 McLaren 570S Coupe | Greenwich, CT                                         │
# │ …        ┆ …             ┆ …                                                                                    │
# │ en       ┆ es            ┆ Fondos de pantalla Dragon Age Inquisition                                            │
# │ en       ┆ fr            ┆ Mini 04-07-18 © Florian Léger - SHARE & DARE-199.jpg                                 │
# │ en       ┆ ja            ┆ NOCONA BLACK OSTRICH LEATHER WESTERN COWBOY ROCKABILLY DANCE BOOTS SIZE 4 B          │
# │ en       ┆ fr            ┆ Red Dead Online semaine chasseur primes                                              │
# │ en       ┆ es            ┆ Infactory Blacklight-esmalte de uñas con Glow-in-the-dark-efecto: Amazon.es: Belleza │
# └──────────┴───────────────┴──────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Non English Captions

df_train.filter(
 (pl.col('lang_detected') != 'en')
)['LANGUAGE', 'lang_detected', 'caption']#.sample(10)
# Out:
# shape: (3_993, 3)
# ┌──────────┬───────────────┬───────────────────────────────────────────────────────────────────────────────────────┐
# │ LANGUAGE ┆ lang_detected ┆ caption                                                                               │
# │ ---      ┆ ---           ┆ ---                                                                                   │
# │ str      ┆ str           ┆ str                                                                                   │
# ╞══════════╪═══════════════╪═══════════════════════════════════════════════════════════════════════════════════════╡
# │ sw       ┆ fr            ┆ Odisha - 2 : Simlipal                                                                 │
# │ lt       ┆ es            ┆ ¡Ánimo juventud! (2020) 1080p WEB-DL Latino                                           │
# │ de       ┆ de            ┆ """ND Filter - auch """"Sonnenbrille für das Objektiv"""" genannt"""                  │
# │ ko       ┆ ko            ┆ 이용매뉴얼_Page_16.png                                                                │
# │ zh       ┆ zh            ┆ 麗寶-天空之夢 - 臺中市 - 旅遊美食討論區 - Mobile01                                    │
# │ …        ┆ …             ┆ …                                                                                     │
# │ es       ┆ es            ┆ Villa a la venta en la Cala de la Granadella con vistas al mar - Javea - Costa Blanca │
# │ en       ┆ es            ┆ Infactory Blacklight-esmalte de uñas con Glow-in-the-dark-efecto: Amazon.es: Belleza  │
# │ nolang   ┆ nl            ┆ weddingblogmannring-151.jpg                                                           │
# │ ja       ┆ es            ┆ SOFABAB                                                                               │
# │ ja       ┆ es            ┆ SOFABAB                                                                               │
# └──────────┴───────────────┴───────────────────────────────────────────────────────────────────────────────────────┘
